# %% [markdown]
# # Pipeline Demo
# Test all three pipeline entry points: text, audio file, and microphone.

# %%
from pipeline.pipeline import LanguageControlPipeline

pipe = LanguageControlPipeline()
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:03<00:00, 37.6MiB/s]

# %% [markdown]
# ## Helper — Pretty print results

# %%
def show(result):
    cmd = result["command"]
    mag = cmd.magnitude.value if cmd.magnitude else "None"
    val = f"{cmd.value_mm}mm" if cmd.value_mm else "None"
    print(f"Text:      {result['text']}")
    print(f"Action:    {cmd.action.value}")
    print(f"Magnitude: {mag} ({val})")
    print(f"Confidence:{cmd.confidence:.2f}")
    print(f"Source:    {result['source']}")
    print(f"Valid:     {result['valid']} — {result['message']}")
    print(f"Latency:   STT={result['latency_stt_ms']:.1f}ms  Parse={result['latency_parse_ms']:.1f}ms")

# %% [markdown]
# ---
# ## 1. Text Input
# Skips Whisper — sends text straight to the LLM parser (with regex fallback).
# Change the string below to test any command.

# %%
result = pipe.process_text("up stop")
show(result)
# Out:
# Text:      up stop
# Action:    MOVE_UP
# Magnitude: None (None)
# Confidence:0.90
# Source:    llm
# Valid:     True — ok
# Latency:   STT=0.0ms  Parse=1871.2ms

# %% [markdown]
# ---
# ## 2. Audio File
# Full pipeline: Whisper transcribes the file, then parses the text.
#
# To create a test WAV file, run the cell below first, then process it.

# %%
# Record a short clip and save it (or provide your own WAV path)
from stt.audio_recorder import AudioRecorder

recorder = AudioRecorder()
print("Say a command into your mic:")
audio = recorder.record_fixed_duration(duration_seconds=3.0)
recorder.save_wav(audio, "demo/test_clip.wav")
print("Saved to demo/test_clip.wav")
# Out:
# Say a command into your mic:
# ---------------------------------------------------------------------------
# PortAudioError                            Traceback (most recent call last)
# Cell In[13], line 6
#       4 recorder = AudioRecorder()
#       5 print("Say a command into your mic:")
# ----> 6 audio = recorder.record_fixed_duration(duration_seconds=3.0)
#       7 recorder.save_wav(audio, "demo/test_clip.wav")
#       8 print("Saved to demo/test_clip.wav")
#
# File ~/Projects/G1_voice_control/stt/audio_recorder.py:75, in AudioRecorder.record_fixed_duration(self, duration_seconds)
#      73 num_samples = int(self.sample_rate * duration_seconds)
#      74 logger.info("Recording %.1fs of audio...", duration_seconds)
# ---> 75 audio = sd.rec(
#      76     num_samples,
#      77     samplerate=self.sample_rate,
#      78     channels=self.channels,
#      79     dtype="float32",
#      80 )
#      81 sd.wait()
#      82 audio = audio.flatten()
#
# File ~/miniconda3/envs/voice_control/lib/python3.11/site-packages/sounddevice.py:284, in rec(frames, samplerate, channels, dtype, out, mapping, blocking, **kwargs)
#     281     ctx.read_indata(indata)
#     282     ctx.callback_exit()
# --> 284 ctx.start_stream(InputStream, samplerate, ctx.input_channels,
#     285                  ctx.input_dtype, callback, blocking, **kwargs)
#     286 return out
#
# File ~/miniconda3/envs/voice_control/lib/python3.11/site-packages/sounddevice.py:2664, in _CallbackContext.start_stream(self, StreamClass, samplerate, channels, dtype, callback, blocking, **kwargs)
#    2661 def start_stream(self, StreamClass, samplerate, channels, dtype, callback,
#    2662                  blocking, **kwargs):
#    2663     stop()  # Stop previous playback/recording
# -> 2664     self.stream = StreamClass(samplerate=samplerate,
#    2665                               channels=channels,
#    2666                               dtype=dtype,
#    2667                               callback=callback,
#    2668                               finished_callback=self.finished_callback,
#    2669                               **kwargs)
#    2670     self.stream.start()
#    2671     global _last_callback
#
# File ~/miniconda3/envs/voice_control/lib/python3.11/site-packages/sounddevice.py:1457, in InputStream.__init__(self, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback)
#    1425 def __init__(self, samplerate=None, blocksize=None,
#    1426              device=None, channels=None, dtype=None, latency=None,
#    1427              extra_settings=None, callback=None, finished_callback=None,
#    1428              clip_off=None, dither_off=None, never_drop_input=None,
#    1429              prime_output_buffers_using_stream_callback=None):
#    1430     """PortAudio input stream (using NumPy).
#    1431
#    1432     This has the same methods and attributes as `Stream`, except
#    (...)   1455
#    1456     """
# -> 1457     _StreamBase.__init__(self, kind='input', wrap_callback='array',
#    1458                          **_remove_self(locals()))
#
# File ~/miniconda3/envs/voice_control/lib/python3.11/site-packages/sounddevice.py:833, in _StreamBase.__init__(self, kind, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback, userdata, wrap_callback)
#     830         samplerate = isamplerate
#     831 else:
#     832     parameters, self._dtype, self._samplesize, samplerate = \
# --> 833         _get_stream_parameters(kind, device, channels, dtype, latency,
#     834                                extra_settings, samplerate)
#     835     self._device = parameters.device
#     836     self._channels = parameters.channelCount
#
# File ~/miniconda3/envs/voice_control/lib/python3.11/site-packages/sounddevice.py:2750, in _get_stream_parameters(kind, device, channels, dtype, latency, extra_settings, samplerate)
#    2747 if samplerate is None:
#    2748     samplerate = default.samplerate
# -> 2750 info = query_devices(device)
#    2751 if channels is None:
#    2752     channels = info['max_' + kind + '_channels']
#
# File ~/miniconda3/envs/voice_control/lib/python3.11/site-packages/sounddevice.py:577, in query_devices(device, kind)
#     575 info = _lib.Pa_GetDeviceInfo(device)
#     576 if not info:
# --> 577     raise PortAudioError(f'Error querying device {device}')
#     578 assert info.structVersion == 2
#     579 name_bytes = _ffi_string(info.name)
#
# PortAudioError: Error querying device -1

# %%
result = pipe.process_audio_file("demo/test_clip.wav")
show(result)

# %% [markdown]
# ---
# ## 3. Live Microphone (Push-to-Talk)
# Press ENTER to start recording, speak your command, press ENTER to stop.

# %%
result = pipe.process_microphone()
show(result)
# Out:
# ---------------------------------------------------------------------------
# PortAudioError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 result = pipe.process_microphone()
#       2 show(result)
#
# File ~/Projects/G1_voice_control/pipeline/pipeline.py:110, in LanguageControlPipeline.process_microphone(self)
#     104 def process_microphone(self) -> dict:
#     105     """Full pipeline: push-to-talk -> transcription -> command.
#     106
#     107     Returns:
#     108         Result dict with command, source, validity, and latency.
#     109     """
# --> 110     audio = self.recorder.record_push_to_talk()
#     112     start_stt = time.perf_counter()
#     113     result = self.stt.transcribe_array(audio)
#
# File ~/Projects/G1_voice_control/stt/audio_recorder.py:46, in AudioRecorder.record_push_to_talk(self)
#      43 input("Press ENTER to start recording...")
#      44 recording.set()
# ---> 46 stream = sd.InputStream(
#      47     samplerate=self.sample_rate,
#      48     channels=self.channels,
#      49     dtype="float32",
#      50     callback=callback,
#      51 )
#      52 with stream:
#      53     input("Recording... Press ENTER to stop.")
#
# File ~/miniconda3/envs/voice_control/lib/python3.11/site-packages/sounddevice.py:1457, in InputStream.__init__(self, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback)
#    1425 def __init__(self, samplerate=None, blocksize=None,
#    1426              device=None, channels=None, dtype=None, latency=None,
#    1427              extra_settings=None, callback=None, finished_callback=None,
#    1428              clip_off=None, dither_off=None, never_drop_input=None,
#    1429              prime_output_buffers_using_stream_callback=None):
#    1430     """PortAudio input stream (using NumPy).
#    1431
#    1432     This has the same methods and attributes as `Stream`, except
#    (...)   1455
#    1456     """
# -> 1457     _StreamBase.__init__(self, kind='input', wrap_callback='array',
#    1458                          **_remove_self(locals()))
#
# File ~/miniconda3/envs/voice_control/lib/python3.11/site-packages/sounddevice.py:833, in _StreamBase.__init__(self, kind, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback, userdata, wrap_callback)
#     830         samplerate = isamplerate
#     831 else:
#     832     parameters, self._dtype, self._samplesize, samplerate = \
# --> 833         _get_stream_parameters(kind, device, channels, dtype, latency,
#     834                                extra_settings, samplerate)
#     835     self._device = parameters.device
#     836     self._channels = parameters.channelCount
#
# File ~/miniconda3/envs/voice_control/lib/python3.11/site-packages/sounddevice.py:2750, in _get_stream_parameters(kind, device, channels, dtype, latency, extra_settings, samplerate)
#    2747 if samplerate is None:
#    2748     samplerate = default.samplerate
# -> 2750 info = query_devices(device)
#    2751 if channels is None:
#    2752     channels = info['max_' + kind + '_channels']
#
# File ~/miniconda3/envs/voice_control/lib/python3.11/site-packages/sounddevice.py:577, in query_devices(device, kind)
#     575 info = _lib.Pa_GetDeviceInfo(device)
#     576 if not info:
# --> 577     raise PortAudioError(f'Error querying device {device}')
#     578 assert info.structVersion == 2
#     579 name_bytes = _ffi_string(info.name)
#
# PortAudioError: Error querying device -1
